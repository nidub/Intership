# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('tumbzilla_labels.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                         img_source  length  \
# 0           0  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...    1583
# 1           1  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...    2501
# 2           2  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...    1513
# 3           3  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...    1710
# 4           4  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...    1694
#
#    nb_views quality                                            title  \
# 0    127450     LOW                                  Tease then suck
# 1    480620     LOW                        Two hot chick on one dick
# 2     99720     LOW  Chick stretches her pussy and blows for the cam
# 3    598820     LOW                             Fucking my neighbour
# 4    155850     LOW      Small titted whore sucking a cock for lunch
#
#                                           video_link  voting     categories  \
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0                                         img_source  length  \
# 191527      191527  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...    2774
# 191528      191528  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...     528
# 191529      191529  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...     672
# 191530      191530  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...     535
# 191531      191531  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...     460
#
#         nb_views quality                                              title  \
# 191527    257540     LOW                                      Czech taxi 39
# 191528     73960     LOW        Casanova Holmes - Quality Vintage 1970s XXX
# 191529    419960      HD             19 Year Old Blonde Fuck in a threesome
# 191530    216150     LOW                             Virtual Sex - Anya Ivy
# 191531    201700      HD  Brazzers - Ebony teen Peyton Sweet loves white...
#
# ...

# %%
df.shape
# Out:
# (191532, 10)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'img_source', 'length', 'nb_views', 'quality', 'title',
#        'video_link', 'voting', 'categories', 'tags'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %%
df.duplicated().sum()
# Out:
# 6

# %%
df = df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# img_source      0
# length          0
# nb_views        0
# quality         0
# title           0
# video_link      0
# voting          0
# categories    353
# tags          353
# dtype: int64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191173 entries, 0 to 191531
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   img_source  191173 non-null  object
#  1   length      191173 non-null  int64
#  2   nb_views    191173 non-null  int64
#  3   quality     191173 non-null  object
#  4   title       191173 non-null  object
#  5   video_link  191173 non-null  object
#  6   voting      191173 non-null  int64
#  7   categories  191173 non-null  object
#  8   tags        191173 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 14.6+ MB

# %%
df.describe()
# Out:
#              length      nb_views         voting
# count  1.911730e+05  1.911730e+05  191173.000000
# mean   8.395711e+02  4.174042e+05      77.478933
# std    2.895393e+03  1.037438e+06       6.609911
# min    5.000000e+00  1.020000e+03      36.000000
# 25%    3.750000e+02  8.527000e+04      73.000000
# 50%    6.010000e+02  1.723500e+05      78.000000
# 75%    1.065000e+03  3.817400e+05      82.000000
# max    1.218521e+06  1.134600e+08      95.000000

# %%
df.nunique()
# Out:
# img_source    191168
# length          5054
# nb_views       59211
# quality            2
# title         187859
# video_link    191168
# voting            43
# categories     59116
# tags          187958
# dtype: int64

# %%
df1 = df.copy()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df['quality'].unique()
# Out:
# array(['LOW', 'HD'], dtype=object)

# %%
df['quality'].value_counts()
# Out:
# LOW    123102
# HD      68071
# Name: quality, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot('quality', data = df, palette = 'hls')
plt.show()

# %%
label_data = df['quality'].value_counts()

explode = (0.1, 0.1)
plt.figure(figsize=(14, 10))
patches, texts, pcts = plt.pie(label_data,
                               labels = label_data.index,
                               colors = ['blue', 'red'],
                               pctdistance = 0.65,
                               shadow = True,
                               startangle = 90,
                               explode = explode,
                               autopct = '%1.1f%%',
                               textprops={ 'fontsize': 25,
                                           'color': 'black',
                                           'weight': 'bold',
                                           'family': 'serif' })
plt.setp(pcts, color='white')

hfont = {'fontname':'serif', 'weight': 'bold'}
plt.title('Quality', size=20, **hfont)

centre_circle = plt.Circle((0,0),0.40,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.show()

# %%
df['voting'].unique()
# Out:
# array([84, 79, 77, 80, 86, 78, 82, 85, 75, 76, 83, 81, 88, 72, 70, 73, 89,
#        93, 90, 62, 69, 71, 65, 87, 64, 74, 60, 91, 61, 68, 67, 63, 66, 92,
#        94, 57, 43, 55, 56, 50, 38, 36, 95], dtype=int64)

# %%
df['voting'].value_counts()
# Out:
# 78    11335
# 77    11266
# 79    11157
# 80    10759
# 76    10590
# 81    10051
# 75     9786
# 82     9355
# 74     8918
# 83     8851
# 84     8324
# 73     7885
# 85     7587
# 72     6996
# 86     6849
# 71     6055
# 87     5775
# 70     5340
# 88     4730
# 69     4507
# 68     3996
# 89     3367
# 67     3333
# 66     2734
# 65     2444
# 64     2029
# 63     1789
# 62     1493
# 61     1383
# 90     1357
# 60      662
# 91      353
# 92       73
# 93       27
# 94        4
# 50        3
# 57        2
# 55        2
# 38        2
# 43        1
# 56        1
# 36        1
# 95        1
# Name: voting, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot('voting', data = df, palette = 'hls')
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.histplot(df['voting'], bins = 10, kde = True, palette = 'hls')
plt.show()

# %%
df['title'].loc[df['title'].str.contains('سكس نار')]
# Out:
# 37927         سكس نار
# 59412         سكس نار
# 131337        سكس نار
# 151966        سكس نار
# 159575        سكس نار
# 163957        سكس نار
# 164047        سكس نار
# 165415    سكس سكس نار
# 168331        سكس نار
# 179475        سكس نار
# 182955        سكس نار
# 186733        سكس نار
# 190114        سكس نار
# Name: title, dtype: object

# %%
for col in ['title','categories','tags']:
    df[col] = df[col].str.replace('سكس نار','Firefighters') 
    df[col] = df[col].str.replace('\d+','') 
    df[col] = df[col].str.replace(r'[_,-]+',' ') 
    df[col] = df[col].str.replace(r'\bScene\b','').str.strip()

# %%
df
# Out:
#                                                img_source  length  nb_views  \
# 0       http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...    1583    127450
# 1       http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...    2501    480620
# 2       http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...    1513     99720
# 3       http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...    1710    598820
# 4       http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...    1694    155850
# ...                                                   ...     ...       ...
# 191527  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...    2774    257540
# 191528  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...     528     73960
# 191529  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...     672    419960
# 191530  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...     535    216150
# 191531  http://cdn-d-img.pornhub.com/m=eafT8daaaa/vide...     460    201700
#
# ...

# %%
most_viewed_title = df[['nb_views','title']].sort_values(by='nb_views', 
                                                         ascending=False).head(10)
most_viewed_title.sort_values(by='nb_views',ascending=True, inplace=True)

# %%
plt.figure(figsize=(15,10))
sns.barplot(y=most_viewed_title['title'], x=most_viewed_title['nb_views'], 
            palette = 'hls')
plt.xticks(rotation= 90)
plt.ylabel('Video Titles')
plt.xlabel('Number of views')
plt.title('Most viewed videos')
plt.show()

# %%
most_viewed_cat = df[['nb_views','categories']].sort_values(by='nb_views', 
                                                            ascending=False).head(10)
most_viewed_cat.sort_values(by='nb_views',ascending=True, inplace=True)

# %%
plt.figure(figsize=(15,10))
sns.barplot(y=most_viewed_cat['categories'], x=most_viewed_cat['nb_views'],
               palette = 'hls')
plt.xticks(rotation= 90)
plt.ylabel('Categories')
plt.xlabel('Number of views')
plt.title('Most viewed categories')
plt.show()

# %%
most_voted_cat = df[['voting','title']].sort_values(by='voting', 
                                                    ascending=False).head(20)
most_voted_cat.sort_values(by='voting',ascending=True, inplace=True)

# %%
plt.figure(figsize=(15,10))
sns.barplot(y=most_voted_cat['title'], x=most_voted_cat['voting'], 
            palette = 'hls')
plt.xticks(rotation= 90)
plt.ylabel('Video Titles')
plt.xlabel('Votings')
plt.title('Most voted videos')
plt.show()

# %%
df2 = df[['nb_views','length']].sort_values(by='nb_views', ascending=False).head(100)

# %%
plt.figure(figsize=(15,10))
sns.barplot(y=df2['nb_views'], x=df2['length'], ci = None, 
            palette = 'hls')
plt.xticks(rotation= 90)
plt.ylabel('Number of views')
plt.xlabel('Length of videos')
plt.title('Length of videos x Number of views')
plt.show()

# %%
plt.figure(figsize=(20,8))
labels = ['HD viewers','Low Quality viewers']
sizes = [
    np.array(df['nb_views'].loc[df['quality']=='HD']).sum(),
    np.array(df['nb_views'].loc[df['quality']=='LOW']).sum()
]
colors = ['red', 'blue']
explode = (0.1, 0.1)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(12,8))
labels = ['HD video voters','Low Quality video voters']
sizes = [
    np.array(df['voting'].loc[df['quality']=='HD']).sum(),
    np.array(df['voting'].loc[df['quality']=='LOW']).sum()
]
colors = ['blue', 'red']
explode = (0.1, 0.1)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=40)
 
plt.axis('equal')
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
from nltk.corpus import stopwords

# %%
stopwords = set(STOPWORDS)
wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=1500,
                          max_font_size=200, 
                          width=1000, height=600,
                          random_state=69,
                         ).generate(" ".join(df['tags'].astype(str)))

fig = plt.figure(figsize = (12,12))
plt.imshow(wordcloud)
plt.title("Most used words in Tags - Word Cloud", fontsize=18)
plt.axis('off')
plt.show()

# %%
wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=1500,
                          max_font_size=200, 
                          width=1000, height=600,
                          random_state=69,
                         ).generate(" ".join(df['categories'].astype(str)))

fig = plt.figure(figsize = (12,12))
plt.imshow(wordcloud)
plt.title("Most used words in Categories - Word Cloud", fontsize=18)
plt.axis('off')
plt.show()

# %%
wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=1500,
                          max_font_size=200, 
                          width=1000, height=600,
                          random_state=69,
                         ).generate(" ".join(df['title'].astype(str)))

fig = plt.figure(figsize = (12,12))
plt.imshow(wordcloud)
plt.title("Most used words in Titles - Word Cloud", fontsize=18)
plt.axis('off')
plt.show()

# %%
df_new = df.copy()

# %%
import re
import string

# %%
def cleaning_text(text):
    text = text.lower()
    text = re.sub('😤', "", text)
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('[‘’“”…]', '', text)
    return text

cleaning = lambda x: cleaning_text(x)

# %%
df_new['tags'] = df_new.tags.apply(cleaning)

# %%
df_new['tags']
# Out:
# 0                       blowjob oral  fullvideo strip tease
# 1         oral blonde threesome blowjob kissing tight se...
# 2         blowjob pussy fingering oral  fullvideo stretc...
# 3         rubbing oral blonde busty blowjob hardcore fac...
# 4         rubbing oral blowjob fingering masturbation st...
#                                 ...
# 191527    public euro czech car point of view milf reali...
# 191528    hairy armpits female friendly  deltaofvenus jo...
# 191529    amateur natural tits doggy style teen babe you...
# 191530    amateur natural tits teen teasing joi virtual ...
# 191531    heels teen brazzers black young pounded orgasm...
# Name: tags, Length: 191173, dtype: object

# %%
from textblob import TextBlob

# %%
TextBlob(df_new['tags'][4]).ngrams(1)
# Out:
# [WordList(['rubbing']),
#  WordList(['oral']),
#  WordList(['blowjob']),
#  WordList(['fingering']),
#  WordList(['masturbation']),
#  WordList(['striptease']),
#  WordList(['pov']),
#  WordList(['cumshot']),
#  WordList(['facial']),
#  WordList(['smalltits']),
#  WordList(['strip']),
#  WordList(['tease']),
#  WordList(['firm']),
#  WordList(['suck'])]

# %%
TextBlob(df_new['tags'][4]).ngrams(2)
# Out:
# [WordList(['rubbing', 'oral']),
#  WordList(['oral', 'blowjob']),
#  WordList(['blowjob', 'fingering']),
#  WordList(['fingering', 'masturbation']),
#  WordList(['masturbation', 'striptease']),
#  WordList(['striptease', 'pov']),
#  WordList(['pov', 'cumshot']),
#  WordList(['cumshot', 'facial']),
#  WordList(['facial', 'smalltits']),
#  WordList(['smalltits', 'strip']),
#  WordList(['strip', 'tease']),
#  WordList(['tease', 'firm']),
#  WordList(['firm', 'suck'])]

# %%
TextBlob(df_new['tags'][4]).ngrams(3)
# Out:
# [WordList(['rubbing', 'oral', 'blowjob']),
#  WordList(['oral', 'blowjob', 'fingering']),
#  WordList(['blowjob', 'fingering', 'masturbation']),
#  WordList(['fingering', 'masturbation', 'striptease']),
#  WordList(['masturbation', 'striptease', 'pov']),
#  WordList(['striptease', 'pov', 'cumshot']),
#  WordList(['pov', 'cumshot', 'facial']),
#  WordList(['cumshot', 'facial', 'smalltits']),
#  WordList(['facial', 'smalltits', 'strip']),
#  WordList(['smalltits', 'strip', 'tease']),
#  WordList(['strip', 'tease', 'firm']),
#  WordList(['tease', 'firm', 'suck'])]

# %%
freq_Sw = pd.Series(' '.join(df_new['tags']).split()).value_counts()[:20]

# %%
freq_Sw
# Out:
# tits        143989
# big         127604
# blowjob      76050
# ass          70981
# pussy        65839
# brunette     56598
# cumshot      51464
# natural      45337
# blonde       42711
# hardcore     39880
# amateur      37341
# teen         35822
# cock         34932
# small        34018
# shaved       32627
# boobs        30528
# young        30185
# facial       30135
# girl         29360
# dick         29303
# dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(min_df = 1, max_df = 0.9)
X = vectorizer.fit_transform(df_new["tags"])
word_freq_df = pd.DataFrame({'term': vectorizer.get_feature_names(), 'occurrences':np.asarray(X.sum(axis=0)).ravel().tolist()})
word_freq_df['frequency'] = word_freq_df['occurrences']/np.sum(word_freq_df['occurrences'])
print(word_freq_df.sort_values('occurrences',ascending = False).head())
# Out:
#           term  occurrences  frequency
# 21711     tits       143990   0.046159
# 2031       big       127604   0.040906
# 2490   blowjob        76051   0.024380
# 1094       ass        70982   0.022755
# 17078    pussy        65839   0.021106

# %%
def get_top_n2_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(2,2),  #for tri-gram, put ngram_range=(3,3)
            max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]

# %%
top2_words = get_top_n2_words(df_new["tags"], n=200) 
top2_df = pd.DataFrame(top2_words)
top2_df.columns=["Bi-gram", "Freq"]
top2_df.head()
# Out:
#         Bi-gram   Freq
# 0      big tits  48775
# 1  natural tits  37670
# 2    small tits  28788
# 3      big dick  22089
# 4     big boobs  21820

# %%
top20_bigram = top2_df.iloc[0:20,:]
fig = plt.figure(figsize = (25, 7))
plot=sns.barplot(x=top20_bigram["Bi-gram"],y=top20_bigram["Freq"])
plot.set_xticklabels(rotation=45,labels = top20_bigram["Bi-gram"])
plt.show()

# %%
def get_top_n3_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(3,3), 
           max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]

# %%
top3_words = get_top_n3_words(df_new["tags"], n=200)
top3_df = pd.DataFrame(top3_words)
top3_df.columns=["Tri-gram", "Freq"]
top3_df
# Out:
#                   Tri-gram   Freq
# 0             girl on girl  11034
# 1            point of view   8352
# 2             cum in mouth   3964
# 3        big tits brunette   3797
# 4            tits big tits   3288
# ..                     ...    ...
# 195  doggystyle small tits    461
# 196        boobs fake tits    458
# 197     small tits amateur    458
# 198           close up big    458
# 199        on girl natural    457
#
# [200 rows x 2 columns]

# %%
top20_trigram = top3_df.iloc[0:20,:]
fig = plt.figure(figsize = (25, 7))
plot=sns.barplot(x=top20_trigram["Tri-gram"],y=top20_trigram["Freq"])
plot.set_xticklabels(rotation=45,labels = top20_trigram["Tri-gram"])
plt.show()

# %%
Loading the libraries
Loading the data
Some preprocessing
Most viewed videos
Most viewed categories
Most voted categories
Length of video vs Number of views
Quality of video vs Number of views
Length of video vs Voting of video
Quality of video vs Voting of video
Most used words in Tags
Most used words in Categories
Most used words in Titles
Data Cleaning
Unigarm, Bigram, Trigram
Count Vectorization
Data Visua;ization - Bigram and Trigram
